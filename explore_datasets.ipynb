# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Glassdoor Reviews

# %%
gd = pd.read_csv("glassdoor_reviews.csv")
print(gd.shape)
gd.head()
# Out:
# (838566, 18)
#                     firm date_review              job_title  \
# 0  AFH-Wealth-Management  2015-04-05
# 1  AFH-Wealth-Management  2015-12-11   Office Administrator
# 2  AFH-Wealth-Management  2016-01-28   Office Administrator
# 3  AFH-Wealth-Management  2016-04-16
# 4  AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                               current                      location  \
# 0                    Current Employee                           NaN
# 1  Current Employee, more than 1 year  Bromsgrove, England, England
# 2  Current Employee, less than 1 year  Bromsgrove, England, England
# 3                    Current Employee                           NaN
# 4  Current Employee, more than 1 year  Bromsgrove, England, England
#
#    overall_rating  work_life_balance  culture_values  diversity_inclusion  \
# 0               2                4.0             3.0                  NaN
# ...

# %%
gd.dtypes
# Out:
# firm                       str
# date_review                str
# job_title                  str
# current                    str
# location                   str
# overall_rating           int64
# work_life_balance      float64
# culture_values         float64
# diversity_inclusion    float64
# career_opp             float64
# comp_benefits          float64
# senior_mgmt            float64
# recommend                  str
# ceo_approv                 str
# outlook                    str
# headline                   str
# pros                       str
# cons                       str
# dtype: object

# %%
gd.isnull().sum()
# Out:
# firm                        0
# date_review                 0
# job_title                   0
# current                     0
# location               297343
# overall_rating              0
# work_life_balance      149894
# culture_values         191373
# diversity_inclusion    702500
# career_opp             147501
# comp_benefits          150082
# senior_mgmt            155876
# recommend                   0
# ceo_approv                  0
# outlook                     0
# headline                 2590
# pros                        2
# cons                       13
# dtype: int64

# %%
gd.sample(5)[[c for c in gd.columns if gd[c].dtype == "object"]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [796643, 316048, 171455, 306413, 398224]

# %%
gd['pros'].head(10).values
# Out:
# <StringArray>
# [                                                                                     'Very friendly and welcoming to new staff. Easy going ethic.',
#                                                                                                     'Friendly, helpful and hard-working colleagues',
#                                                                                            'Easy to get the job even without experience in finance',
#                                                                                                                           'Nice staff to work with',
#                                                                                                             'Easy to get the job, Nice colleagues.',
#                'Some good people to work with.\n\nFlexible working.\n\nOut of hours language classes and aerobics.\n\nFinancial support for exams.',
# ...

# %%
gd['cons'].head(10).values
# Out:
# <StringArray>
# [                                                                                                                                                                                                      'Poor salaries, poor training and communication.',
#                                                                                                                             'Poor salary which doesn't improve much with progression, no incentive to work harder, high turnover of staff, poor systems',
#                       'Very low salary, poor working conditions, very little training provided but high expectations. Micro management are young, inexperienced and superficial girls who are not able to provide guidance and support for their teams.',
# ...

# %% [markdown]
# ## UK Petitions

# %%
pet = pd.read_csv("uk_petitions_final.csv")
print(pet.shape)
pet.head()
# Out:
# (11662, 20)
#    petition_id                                             action  \
# 0       700001  Fund reconstruction surgery and psychosexual t...
# 1       700005  Apply for the UK to join the European Union as...
# 2       700006                          Rejoin the European Union
# 3       700007  Require dating apps to ensure ID and DBS check...
# 4       700009  Fund Covid booster vaccines for all, with prio...
#
#                                           background  \
# 0  We urge the Government to support FGM survivor...
# 1  I believe joining the EU would boost the econo...
# 2  The UK Government should seek to rejoin the Eu...
# 3  I believe to better protect the public from of...
# 4  Long Covid can ruin lives and cause financial ...
#
#                                   additional_details     state  \
# 0  I know firsthand the physical and emotional ch...    closed
# 1  I think the Single Market would bring inward i...    closed
# ...

# %%
pet.dtypes
# Out:
# petition_id                      int64
# action                             str
# background                         str
# additional_details                 str
# state                              str
# signature_count                  int64
# created_at                         str
# updated_at                         str
# rejected_at                        str
# opened_at                          str
# closed_at                          str
# government_response_at             str
# debate_threshold_reached_at        str
# scheduled_debate_date              str
# debated                        float64
# debate_overview                    str
# government_response_summary        str
# government_response_body           str
# rejection_code                     str
# rejection_details                  str
# dtype: object

# %%
pet.isnull().sum()
# Out:
# petition_id                        0
# action                             0
# background                         0
# additional_details               570
# state                              0
# signature_count                    0
# created_at                         0
# updated_at                         0
# rejected_at                     5220
# opened_at                       6441
# closed_at                       8423
# government_response_at         11391
# debate_threshold_reached_at    11596
# scheduled_debate_date          11612
# debated                        11662
# debate_overview                11661
# government_response_summary    11391
# government_response_body       11391
# rejection_code                  5220
# rejection_details               5398
# dtype: int64

# %%
pet.sample(5)[[c for c in pet.columns if pet[c].dtype == "object"]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [6473, 1605, 1823, 4401, 9196]

# %% [markdown]
# ## Chicago Food Inspections

# %%
chi = pd.read_csv("Food_Inspections_20260410.csv")
print(chi.shape)
chi.head()
# Out:
# (308431, 17)
#    Inspection ID                     DBA Name                     AKA Name  \
# 0        2633683                POP UP BAGELS                POP UP BAGELS
# 1        2633675  Union Sushi + BBQ + Izakaya  Union Sushi + BBQ + Izakaya
# 2        2633665  Union Sushi + BBQ + Izakaya  Union Sushi + BBQ + Izakaya
# 3        2633641               PENNY'S ROSCOE          PENNY'S NOODLE SHOP
# 4        2633638              ALI'S FOOD MART              ALI'S FOOD MART
#
#    License #  Facility Type             Risk                  Address  \
# 0  3078489.0     Restaurant  Risk 2 (Medium)       2321 N LINCOLN AVE
# 1  3073929.0     Restaurant     Risk 3 (Low)      1538 N CLYBOURN AVE
# 2  3073928.0     Restaurant    Risk 1 (High)      1538 N CLYBOURN AVE
# 3  2677553.0     Restaurant    Risk 1 (High)     3400 N SHEFFIELD AVE
# 4  2972505.0  Grocery Store  Risk 2 (Medium)  1308 S CENTRAL PARK AVE
#
#       City State      Zip Inspection Date        Inspection Type Results  \
# ...

# %%
chi.dtypes
# Out:
# Inspection ID        int64
# DBA Name               str
# AKA Name               str
# License #          float64
# Facility Type          str
# Risk                   str
# Address                str
# City                   str
# State                  str
# Zip                float64
# Inspection Date        str
# Inspection Type        str
# Results                str
# Violations             str
# Latitude           float64
# Longitude          float64
# Location               str
# dtype: object

# %%
chi.isnull().sum()
# Out:
# Inspection ID          0
# DBA Name               0
# AKA Name            2420
# License #             19
# Facility Type       5323
# Risk                  88
# Address                0
# City                 189
# State                 67
# Zip                   42
# Inspection Date        0
# Inspection Type        1
# Results                0
# Violations         86503
# Latitude            1051
# Longitude           1051
# Location            1051
# dtype: int64

# %%
chi.sample(5)[[c for c in chi.columns if chi[c].dtype == "object"]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [95957, 96609, 131228, 19244, 190202]
